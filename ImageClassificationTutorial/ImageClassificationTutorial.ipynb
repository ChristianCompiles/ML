# %%
import tensorflow as tf
import numpy as np

# %%
filename = 'image1.jpg'

# %%
# loading image--method 1

# %%
from IPython.display import Image
Image(filename = 'image1.jpg', width = 224, height = 224)

# %%
# loading image method2

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('image1.jpg', target_size = (224,224))
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
# loading image--method 3

# %%
import cv2

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg = cv2.resize(imgg, (224, 224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %%
# loading image--method 4

# %%
from PIL import Image

# %%
im = Image.open(filename)

# %%
im = im.resize((224, 224))

# %%
plt.imshow(im)

# %%
# Load deep learning model

# %%
# deep learning model weights (pre-trained)
# MobileNet
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
# MobileNetV2
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
# There are many pre-trained models you can use!

# %%
anymodel = tf.keras.applications.RegNetY080()

# %%
# Phase 1: Creating a Model
# Phase 2: Training a Model
# Phase 3: Test or Validate
# Phase 4: Predict

# %%
# Pre-processing of the image before predicting

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224, 224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis = 0) ## need fourth dimension
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
resized_img.shape
# Out:
# (224, 224, 3)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 864ms/step

# %%
print(predictions)
# Out:
# [[4.60809076e-07 2.46655804e-06 6.12374947e-07 1.48978202e-07
#   1.03403736e-05 4.80364633e-06 1.11968711e-05 6.36510822e-06
#   5.99226769e-05 1.65169604e-06 1.53536902e-07 1.08801508e-07
#   1.74902894e-07 1.41365986e-08 5.81791859e-08 1.30089518e-07
#   2.70513624e-07 1.25716795e-07 2.25719702e-07 2.89861077e-07
#   1.35550764e-07 1.34834113e-06 6.31337343e-07 8.57783903e-07
#   8.20448804e-06 5.25024291e-07 7.45538102e-08 2.30522232e-07
#   2.11572157e-07 2.15576620e-07 5.85568387e-07 6.81346762e-07
#   1.73763198e-07 9.53860763e-06 8.00222260e-05 4.78502557e-07
#   6.15090448e-06 4.99558291e-06 1.67536328e-07 5.48673427e-07
#   1.37514917e-07 1.43791699e-08 1.55807882e-07 1.09838005e-07
#   2.71783762e-07 4.18011439e-07 6.42054516e-08 1.22970812e-06
#   1.16533283e-06 5.10350588e-08 2.35383609e-07 6.38037500e-06
#   2.11960651e-06 2.81310167e-06 3.83998267e-04 2.97103071e-07
#   4.13430789e-05 6.45995442e-07 2.27028750e-06 1.36539472e-06
# ...

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03770679', 'minivan', 0.60358435), ('n04065272', 'recreational_vehicle', 0.053305235), ('n02814533', 'beach_wagon', 0.049014304), ('n03769881', 'minibus', 0.030523181), ('n04467665', 'trailer_truck', 0.028879758)]]

# %%
plt.imshow(img)
